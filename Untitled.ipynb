# %%
import pandas as pd
df=pd.read_csv("testdata.csv")
df
# Out:
#          id organism  control     time     abundance  logscale treatment  \
# 0   Maat5A0        H    False   0.0356  2.638100e+05     False      0.5C
# 1   Maat5A0        H    False  24.0493  2.382800e+05     False      0.5C
# 2   Maat5A0        H    False  51.0301  1.145200e+05     False      0.5C
# 3   Maat5A0        H    False  74.9928  5.003591e+04     False      0.5C
# 4   Maat5A0        H    False  99.0553  4.854889e+03     False      0.5C
# 5   Maat5B0        V    False   0.0522  5.344800e+06     False      0.5C
# 6   Maat5B0        V    False   8.0256  5.114900e+06     False      0.5C
# 7   Maat5B0        V    False  16.0482  3.908000e+06     False      0.5C
# 8   Maat5B0        V    False  24.0221  4.597700e+06     False      0.5C
# 9   Maat5B0        V    False  30.0161  7.471300e+06     False      0.5C
# 10  Maat5B0        V    False  51.0303  3.862100e+07     False      0.5C
# 11  Maat5B0        V    False  75.0612  6.109200e+07     False      0.5C
# ...

# %%
df2=df.iloc[:4]
df2
# Out:
#         id organism  control     time    abundance  logscale treatment  \
# 0  Maat5A0        H    False   0.0356  263810.0000     False      0.5C
# 1  Maat5A0        H    False  24.0493  238280.0000     False      0.5C
# 2  Maat5A0        H    False  51.0301  114520.0000     False      0.5C
# 3  Maat5A0        H    False  74.9928   50035.9093     False      0.5C
#
#             algalHost  Column1
# 0  Micromonas Polaris      NaN
# 1  Micromonas Polaris      NaN
# 2  Micromonas Polaris      NaN
# 3  Micromonas Polaris      NaN

# %%
df3=df.iloc[:,4]
df3
# Out:
# 0     2.638100e+05
# 1     2.382800e+05
# 2     1.145200e+05
# 3     5.003591e+04
# 4     4.854889e+03
# 5     5.344800e+06
# 6     5.114900e+06
# 7     3.908000e+06
# 8     4.597700e+06
# 9     7.471300e+06
# 10    3.862100e+07
# 11    6.109200e+07
# 12    6.293100e+07
# Name: abundance, dtype: float64

# %%
df4=df.iloc[:,4:7]
df4
# Out:
#        abundance  logscale treatment
# 0   2.638100e+05     False      0.5C
# 1   2.382800e+05     False      0.5C
# 2   1.145200e+05     False      0.5C
# 3   5.003591e+04     False      0.5C
# 4   4.854889e+03     False      0.5C
# 5   5.344800e+06     False      0.5C
# 6   5.114900e+06     False      0.5C
# 7   3.908000e+06     False      0.5C
# 8   4.597700e+06     False      0.5C
# 9   7.471300e+06     False      0.5C
# 10  3.862100e+07     False      0.5C
# 11  6.109200e+07     False      0.5C
# 12  6.293100e+07     False      0.5C

# %%
df5=df.iloc[:,3:5]
df5
# Out:
#        time     abundance
# 0    0.0356  2.638100e+05
# 1   24.0493  2.382800e+05
# 2   51.0301  1.145200e+05
# 3   74.9928  5.003591e+04
# 4   99.0553  4.854889e+03
# 5    0.0522  5.344800e+06
# 6    8.0256  5.114900e+06
# 7   16.0482  3.908000e+06
# 8   24.0221  4.597700e+06
# 9   30.0161  7.471300e+06
# 10  51.0303  3.862100e+07
# 11  75.0612  6.109200e+07
# 12  99.0324  6.293100e+07

# %%
import matplotlib.pyplot as plt

# %%
df5.plot.scatter(x="time",y="abundance")
# Out:
# <AxesSubplot:xlabel='time', ylabel='abundance'>
