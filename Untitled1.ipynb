# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
brussard=pd.read_csv("brussard.csv")
brussard
# Out:
#              id organism  control     time    abundance  logscale  treatment  \
# 0   Brussaard4a        H    False   2.1634   17800000.0     False        NaN
# 1   Brussaard4a        H    False   6.0326   17959000.0     False        NaN
# 2   Brussaard4a        H    False   9.8973   20400000.0     False        NaN
# 3   Brussaard4a        H    False  13.6270   18529000.0     False        NaN
# 4   Brussaard4a        H    False  17.0627   20525000.0     False        NaN
# 5   Brussaard4a        H    False  25.2764   22007000.0     False        NaN
# 6   Brussaard4a        H    False  29.1964   20525000.0     False        NaN
# 7   Brussaard4a        H    False  36.8444   18073000.0     False        NaN
# 8   Brussaard4a        H    False  40.1894   17600000.0     False        NaN
# 9   Brussaard4a        H    False  48.4205    9920000.0     False        NaN
# 10  Brussaard4a        H    False  52.2969    6271400.0     False        NaN
# ...

# %%
brussardcontrol=brussard.iloc[12:24]
brussardcontrol
# Out:
#              id organism  control     time   abundance  logscale  treatment  \
# 12  Brussaard4a        H     True   0.0332  17690000.0     False        NaN
# 13  Brussaard4a        H     True   2.1632  17902000.0     False        NaN
# 14  Brussaard4a        H     True   6.0344  17000000.0     False        NaN
# 15  Brussaard4a        H     True   9.8941  22064000.0     False        NaN
# 16  Brussaard4a        H     True  17.0560  24002000.0     False        NaN
# 17  Brussaard4a        H     True  25.2192  27000000.0     False        NaN
# 18  Brussaard4a        H     True  29.1335  28449000.0     False        NaN
# 19  Brussaard4a        H     True  36.8610  34400000.0     False        NaN
# 20  Brussaard4a        H     True  40.1542  36000000.0     False        NaN
# 21  Brussaard4a        H     True  48.2656  40992000.0     False        NaN
# 22  Brussaard4a        H     True  52.1294  43957000.0     False        NaN
# ...

# %%
brussardvirus=brussard.iloc[24:40]
brussardvirus
# Out:
#              id organism  control     time    abundance  logscale  treatment  \
# 24  Brussaard4a        V    False   2.1493  242870000.0     False        NaN
# 25  Brussaard4a        V    False   6.0612  254280000.0     False        NaN
# 26  Brussaard4a        V    False   9.8759  274800000.0     False        NaN
# 27  Brussaard4a        V    False  13.6985  254280000.0     False        NaN
# 28  Brussaard4a        V    False  17.1239  313570000.0     False        NaN
# 29  Brussaard4a        V    False  19.8920  315850000.0     False        NaN
# 30  Brussaard4a        V    False  22.0920  293040000.0     False        NaN
# 31  Brussaard4a        V    False  25.2328  343220000.0     False        NaN
# 32  Brussaard4a        V    False  29.1408  375140000.0     False        NaN
# 33  Brussaard4a        V    False  32.9559  393390000.0     False        NaN
# 34  Brussaard4a        V    False  36.7628  454960000.0     False        NaN
# ...

# %%
brussardinfected=brussard.iloc[0:12]
brussardinfected
# Out:
#              id organism  control     time   abundance  logscale  treatment  \
# 0   Brussaard4a        H    False   2.1634  17800000.0     False        NaN
# 1   Brussaard4a        H    False   6.0326  17959000.0     False        NaN
# 2   Brussaard4a        H    False   9.8973  20400000.0     False        NaN
# 3   Brussaard4a        H    False  13.6270  18529000.0     False        NaN
# 4   Brussaard4a        H    False  17.0627  20525000.0     False        NaN
# 5   Brussaard4a        H    False  25.2764  22007000.0     False        NaN
# 6   Brussaard4a        H    False  29.1964  20525000.0     False        NaN
# 7   Brussaard4a        H    False  36.8444  18073000.0     False        NaN
# 8   Brussaard4a        H    False  40.1894  17600000.0     False        NaN
# 9   Brussaard4a        H    False  48.4205   9920000.0     False        NaN
# 10  Brussaard4a        H    False  52.2969   6271400.0     False        NaN
# ...

# %%
t1=brussardcontrol.time
a1=brussardcontrol.abundance
t2=brussardvirus.time
a2=brussardvirus.abundance
t3=brussardinfected.time
a3=brussardinfected.abundance

# %%
plt.plot(t1,a1,"r",t3,a3,"y")
plt.show()
